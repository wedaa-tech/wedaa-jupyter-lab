# %% [markdown]
# ### Explanation:
#
# #### Normal Distribution:
#
# Generated using np.random.normal with mean (loc) = 0 and standard deviation (scale) = 1.
# The histogram shows a bell-shaped curve, symmetric around the mean.
#
#
# #### Bimodal Distribution:
#
# Created by combining two normal distributions with different means (-2 and 2).
# The histogram displays two distinct peaks, indicating two subgroups in the data.
#
#
# #### Skewed Distribution:
#
# Generated using np.random.lognormal, which produces a right-skewed distribution.
# The histogram shows a long tail on the right, typical of skewed data (e.g., income, time-to-failure).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Create figure with three subplots
plt.figure(figsize=(15, 5))

# 1. Normal Distribution
normal_data = np.random.normal(loc=0, scale=1, size=1000)  # Mean=0, Std=1
plt.subplot(1, 3, 1)
plt.hist(normal_data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 2. Bimodal Distribution (mixture of two normals)
bimodal_data = np.concatenate([
    np.random.normal(loc=-2, scale=1, size=500),
    np.random.normal(loc=2, scale=1, size=500)
])
plt.subplot(1, 3, 2)
plt.hist(bimodal_data, bins=30, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title('Bimodal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 3. Skewed Distribution (using lognormal)
skewed_data = np.random.lognormal(mean=0, sigma=0.5, size=1000)
plt.subplot(1, 3, 3)
plt.hist(skewed_data, bins=30, color='salmon', edgecolor='black', alpha=0.7)
plt.title('Skewed Distribution (Right Skew)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Adjust layout and display
plt.tight_layout()
plt.show()
